# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
data=pd.read_csv("advertising.csv", sep=',')

# %%
# WHAT ARE THE NUMBER OF ROWS AND COLUMNS

data
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
# The dataset has 200 rows and 4 colums

# %%
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
# The above shows the first five rows of the dataset

# %%
# WHAT IS THE INFORMATION OF THE DATASET?

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
# The dataset has no null values and values range from 0 to 199

# %%
# WHAT IS THE DESCRIPTION OF THE DATASET?

data.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
# TV has the maximum value, highest mean and highest standard deviation
# Radio has the minimum value
# Sales has the lowest mean, lowest standard deviation

# %%
# ARE THERE ANY MISSING VALUES IN THE DATASET?

data.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
# There are no null values in the dataset

# %%
data.isnull().sum().plot(kind='bar')
# Out:
# <Axes: >

# %%
# There is no bar on the chart because there are no null values on the dataset

# %%
# WHAT ARE THE NUMBER OF UNIQUE VALUES IN EACH OF THE COLUMNS

print(data["TV"].nunique())
print(data["Radio"].nunique())
print(data["Newspaper"].nunique())
print(data["Sales"].nunique())
# Out:
# 190
# 167
# 172
# 121

# %%
# There are 190, 167, 172 and 121 unique values on TV, Radio, Newspaper and Sales columns respectively

# %% [markdown]
# # DESCRIPTIVE ANALYSIS OF THE DATASET

# %%
# WHAT IS THE DISTRIBUTION OF TV ADVERTISING SPENDING?

plt.figure(figsize=(10,5))
sns.histplot(data['TV'], bins=5)
plt.title('TV Advertising  Spending Distribution')
plt.xlabel('TV Advertising Spending')
plt.ylabel('Frequency')
plt.show()

# %%
# TV values ranging from 175 to 240 have the highest frequency of 48 
# TV values ranging from 120 to 180 have the lowest frequency of 35

# %%
# WHAT IS THE DISTRIBUTION OF RADIO ADVERTISING SPENDING?

plt.figure(figsize=(10,5))
sns.histplot(data['Radio'], bins=5)
plt.title('Radio Advertising Spending Distribution')
plt.xlabel('Radio Advertising Spending')
plt.ylabel('Frequency')
plt.show()

# %%
# Radio values ranging from 0 to 10 have the highest frequency of 50 
# Radio values ranging from 30 to 39 have the lowest frequency of 34

# %%
# WHAT IS THE DISTRIBUTION OF NEWSPAPER ADVERTISING SPENDING?

plt.figure(figsize=(10,5))
sns.histplot(data['Newspaper'], bins=5)
plt.title('Newspaper Advertising Spending Distribution')
plt.xlabel('Newspaper Advertising Spending')
plt.ylabel('Frequency')
plt.show()

# %%
# Newspaper values ranging from o to 19 have the highest frequency of 84 
# Newspaper values ranging from 86 to 170 have the lowest frequency of 0.1

# %%
# WHAT IS THE DISTRIBUTION OF SALES FIGURE?

plt.figure(figsize=(10,5))
sns.histplot(data['Sales'], bins=5)
plt.title('Sales Distribution')
plt.xlabel('Sales')
plt.ylabel('Frequency')
plt.show()

# %%
# Sales values ranging from 17 to 22 have the highest frequency of 64.
# Sales values ranging from 1.2 to 7 have the lowest frequency of 11.

# %%
# To visualize distributions using histogram
plt.figure(figsize=(12,4))
plt.subplot(121)
plt.hist(data['TV'], bins=10, color='red', alpha=1)
plt.title('TV Spending Distribution')
plt.xlabel('TV Spending')
plt.subplot(122)
plt.hist(data['Radio'], bins=10, color='purple', alpha=0.7)
plt.title('Radio Spending Distribution')
plt.xlabel('Radio Spending')
# Out:
# Text(0.5, 0, 'Radio Spending')

# %%
# The above chart shows that TV spending values between 0 to 30 and 210 to 240 had the highest frequency in the TV and Radio column respectively

# %%
# To visualize distributions using histogram
plt.figure(figsize=(12,4))
plt.subplot(121)
plt.hist(data['Newspaper'], bins=10, color='blue', alpha=0.7)
plt.title('Newspaper Spending Distribution')
plt.xlabel('Newspaper Spending')
plt.subplot(122)
plt.hist(data['Sales'], bins=10, color='green', alpha=0.7)
plt.title('Sales Distribution')
plt.xlabel('Sales')
plt.tight_layout()
plt.show()

# %%
# The above chart shows that Newspaper spending and Sales values between 0 to 10 and 17 to 19 had the highest frequencies for Newspaper spending and Sales repectively

# %% [markdown]
# # EXPLORATORY ANALYSIS OF THE DATASET

# %% [markdown]
# # CORRELATION BETWEEN TV, NEWSPAPER, RADIO AND SALES (y axis shows the scale of values for each of the columns)

# %%
sns.boxplot(data=data[['TV']])
plt.title('Boxplot of TV')
plt.show()

# %%
# The boxplot above shows that values on TV column range from 0 to 300, with values from 80 to 230 appearing most in the column

# %%
sns.boxplot(data=data[['Radio']])
plt.title('Boxplot of Radio')
plt.show()

# %%
# The boxplot above shows that values on Radio column range from 0 to 50, with values from 10 to 37 appearing most in the column

# %%
sns.boxplot(data=data[['Newspaper']])
plt.title('Boxplot of Newspaper')
plt.show()

# %%
# The boxplot above shows that values on Newspaper column range from 0 to 90 and above, with values from 11 to 48 appearing most in the column
# It also shows that there are outliers in the Newspaper column.

# %%
sns.boxplot(data=data[['Sales']])
plt.title('Boxplot of Sales')
plt.show()

# %%
# The boxplot above shows that values on Sales column range from 0 to 28, with values from 11 to 19 appearing most in the column

# %%
# IS THERE A CORRELATION BETWEEN TV, RADIO, NEWSPAPER SPENDING AND SALES?

sns.heatmap(data.corr(), annot=True, cmap='viridis');

# %%
# The heatmap above shows that; 
# TV has 90% relationship with Sales = (Positive correlation)
# Radio has 35% relationship with Sales = (Positive correlation)
# Newspaper has 16% relationship with Sales = (Positive correlation)
# Sales has 100% relationship with Sales(itself) = (Positive correlation)

# %%
# THE VALUES USED TO PLOT THE HEATMAP ABOVE

data.corr()
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.054809   0.056648  0.901208
# Radio      0.054809  1.000000   0.354104  0.349631
# Newspaper  0.056648  0.354104   1.000000  0.157960
# Sales      0.901208  0.349631   0.157960  1.000000

# %%
plt.scatter(data['TV'], data["Sales"]);

# %%
# The Scatter plot above shows that there is a linear(strong) relationship between TV and Sales

# %%
plt.scatter(data['Radio'], data["Sales"]);

# %%
# In the above Scatter plot, relationship between Radio and Sales is low

# %%
plt.scatter(data['Newspaper'], data["Sales"]);

# %%
# The Scatter plot above shows that Newspaper has low relationship with Sales
